# %%
import numpy as np, pandas as pd

# %%
df=pd.read_csv("datasets/car_models.csv")
df.head()
# Out:
#    Company          Model Horsepower     Torque  Transmission Type Drivetrain  \
# 0  Ferrari  812 Superfast     789 hp  530 lb-ft  7-speed automatic        RWD
# 1  Ferrari     F8 Tributo     710 hp  568 lb-ft  7-speed automatic        RWD
# 2  Ferrari           Roma     611 hp  560 lb-ft  8-speed automatic        RWD
# 3  Ferrari    Portofino M     612 hp  561 lb-ft  8-speed automatic        RWD
# 4  Ferrari  SF90 Stradale     986 hp  590 lb-ft  8-speed automatic        AWD
#
#         Fuel Economy Number of Doors     Price Model Year Range    Body Type  \
# 0          13/20 mpg               2  $366,712   2018 - Present        Coupe
# 1          15/19 mpg               2  $276,550   2020 - Present        Coupe
# 2          16/24 mpg               2  $218,750   2021 - Present        Coupe
# 3          16/22 mpg               2  $254,475   2021 - Present  Convertible
# 4  18 mpg (combined)               2  $625,000   2020 - Present        Coupe
#
#   Engine Type Number of Cylinders
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Model', 'Horsepower', 'Torque', 'Transmission Type',
#        'Drivetrain', 'Fuel Economy', 'Number of Doors', 'Price',
#        'Model Year Range', 'Body Type', 'Engine Type', 'Number of Cylinders'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              404 non-null    object
#  1   Model                404 non-null    object
#  2   Horsepower           404 non-null    object
#  3   Torque               404 non-null    object
#  4   Transmission Type    404 non-null    object
#  5   Drivetrain           404 non-null    object
#  6   Fuel Economy         399 non-null    object
#  7   Number of Doors      404 non-null    object
#  8   Price                398 non-null    object
#  9   Model Year Range     403 non-null    object
#  10  Body Type            403 non-null    object
#  11  Engine Type          403 non-null    object
#  12  Number of Cylinders  402 non-null    object
# dtypes: object(13)
# memory usage: 41.2+ KB

# %%
df.Company.unique()
# Out:
# array(['Ferrari', 'Mahindra', 'Toyota', 'Ford', 'Chevrolet', 'Nissan',
#        'BMW', 'Mercedes-Benz', 'Audi', 'Volkswagen', 'Porsche',
#        'Rolls-Royce', 'McLaren', 'Lexus', 'Hyundai', 'Kia', 'Mazda',
#        'Subaru', 'Mitsubishi', 'Tesla', 'Dodge', 'Ram', 'Volvo',
#        'Land Rover', 'Jaguar', 'Fiat', 'Alfa Romeo', 'Peugeot', 'Citroën',
#        'Renault', 'Skoda', 'SEAT', 'Opel/Vauxhall', 'Mini', 'Saab',
#        'Bugatti', 'Maserati', 'Lancia', 'Pagani', 'Koenigsegg', 'Genesis',
#        'Polestar', 'Lucid Motors', 'Rivian', 'Faraday Future', 'Alpina',
#        'Cadillac', 'Caterham', 'Chrysler', 'Fisker', 'Infiniti', 'Isuzu',
#        'Lotus', 'Morgan', 'Smart', 'Suzuki', 'Vauxhall', 'Zagato',
#        'Wiesmann', 'Lamborghini', 'Honda', 'Tata Motors'], dtype=object)

# %%
df.Company.value_counts()
# Out:
# Chevrolet         20
# Toyota            16
# Suzuki            16
# Koenigsegg        12
# Renault           11
#                   ..
# Lucid Motors       2
# Smart              2
# Fisker             2
# Faraday Future     2
# Rivian             2
# Name: Company, Length: 62, dtype: int64

# %%
df.Company.value_counts()[df.Company.value_counts() >= 5]
# Out:
# Chevrolet        20
# Toyota           16
# Suzuki           16
# Koenigsegg       12
# Renault          11
# Ferrari          10
# Lamborghini      10
# Opel/Vauxhall    10
# Dodge            10
# Honda             9
# Nissan            9
# Cadillac          9
# Lexus             9
# Subaru            8
# Mini              8
# Volvo             8
# Tata Motors       8
# BMW               8
# SEAT              7
# Skoda             7
# Ford              7
# Hyundai           7
# Vauxhall          7
# Infiniti          7
# Zagato            6
# Isuzu             6
# Audi              6
# Porsche           6
# Mahindra          6
# Mazda             6
# McLaren           6
# Kia               6
# Peugeot           6
# Land Rover        6
# Alpina            5
# Mercedes-Benz     5
# Morgan            5
# Jaguar            5
# Caterham          5
# Citroën           5
# Volkswagen        5
# Lancia            5
# Rolls-Royce       5
# Genesis           5
# Mitsubishi        5
# ...

# %%
df.Company.value_counts()[df.Company.value_counts() >= 5].plot(kind='bar', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (404, 13)

# %%
# df.query("`column name` > @external_variable")
# df.query("column_name > value")

# %%
# df.job_title.value_counts().plot(kind="pie", autopct="",)

# %%
df.query("Company == 'Chevrolet'")
# Out:
#        Company                     Model Horsepower     Torque  \
# 30   Chevrolet                    Camaro    275-650    295-650
# 31   Chevrolet                  Corvette    490-755    465-715
# 32   Chevrolet                     Spark         98         94
# 33   Chevrolet                   Bolt EV        200        266
# 34   Chevrolet                   Equinox    170-252    203-260
# 35   Chevrolet                  Suburban        355        383
# 36   Chevrolet                     Tahoe    355-420    383-460
# 37   Chevrolet            Silverado 1500    285-420    305-460
# 38   Chevrolet                  Colorado    200-308    191-369
# 39   Chevrolet  Silverado HD (2500/3500)    401-445    464-910
# 380  Chevrolet                    Camaro     335 hp  290 lb-ft
# 381  Chevrolet                  Corvette     490 hp  460 lb-ft
# 382  Chevrolet                     Cruze     153 hp  138 lb-ft
# 383  Chevrolet                   Equinox     170 hp  174 lb-ft
# ...

# %%
df.loc[
       (df["Company"] == "Chevrolet") &
       (df["Price"])
       ].shape
# Out:
# (19, 13)

# %%
df.columns

# %%
df.info()

# %%
ax = df['work_year'].plot(kind='hist', figsize=(10,5), bins=10)
ax.axvline(df["work_year"].quantile(.05), color='red')
ax.axvline(df["work_year"].quantile(.95), color='red')

# %%
# highest salary earner
df.loc[df["salary_in_usd"] == df.salary_in_usd.max()]

# %%
avg_salary = df.salary_in_usd.mean()
avg_salary

# %%
df.loc[df["salary_in_usd"] >= avg_salary ].shape
